# %% [markdown]
# <a href="https://colab.research.google.com/github/cuongle2002/dataframe-week-3/blob/main/Medical_fuzzy_logic(BTVNW5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 17.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=1bf52af5b9df45ee244555b55ab4aadca9c7abd61cb671027eb63f79fe1209c1
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
#34725337
import numpy as np
import skfuzzy as fuzz 
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl

fever  = ctrl.Antecedent(np.arange(0,1,0.05), 'fever') 
headache  = ctrl.Antecedent(np.arange(0,1,0.05), 'headache') 
nausea  = ctrl.Antecedent(np.arange(0,1,0.05), 'nausea') 
vomoting  = ctrl.Antecedent(np.arange(0,1,0.05), 'vomiting') 
jaundice  = ctrl.Antecedent(np.arange(0,1,0.05), 'jaundice') 
enlargeliver  = ctrl.Antecedent(np.arange(0,1,0.05), 'enlargeliver') 
jointpain  = ctrl.Antecedent(np.arange(0,1,0.05), 'jointpain') 
bodyweakness = ctrl.Antecedent(np.arange(0,1,0.05), 'bodyweakness') 
dizzniness  = ctrl.Antecedent(np.arange(0,1,0.05), 'dizzniness') 
# loss of appetite
loa  = ctrl.Antecedent(np.arange(0,1,0.05), 'loa') 
mp  = ctrl.Antecedent(np.arange(0,1,0.05), 'mp') 
conclusion = ctrl.Consequent(np.arange(0,1.2,0.05), 'conclusion')

#4 levels
fever['mild'] = fuzz.trimf(fever.universe,[0,0.1,0.25])
fever['moderate'] = fuzz.trimf(fever.universe,[0.25,0.35,0.5])
fever['service'] = fuzz.trimf(fever.universe,[0.5,0.7,0.75])
fever['veryservice'] = fuzz.trimf(fever.universe,[0.7,0.85,1])

headache['mild'] = fuzz.trimf(headache.universe,[0,0.1,0.25])
headache['moderate'] = fuzz.trimf(headache.universe,[0.25,0.35,0.5])
headache['service'] = fuzz.trimf(headache.universe,[0.5,0.7,0.75])
headache['veryservice'] = fuzz.trimf(headache.universe,[0.7,0.85,1])

nausea['mild'] = fuzz.trimf(nausea.universe,[0,0.1,0.25])
nausea['moderate'] = fuzz.trimf(nausea.universe,[0.25,0.35,0.5])
nausea['service'] = fuzz.trimf(nausea.universe,[0.5,0.7,0.75])
nausea['veryservice'] = fuzz.trimf(nausea.universe,[0.7,0.85,1])

vomoting['mild'] = fuzz.trimf(vomoting.universe,[0,0.1,0.25])
vomoting['moderate'] = fuzz.trimf(vomoting.universe,[0.25,0.35,0.5])
vomoting['service'] = fuzz.trimf(vomoting.universe,[0.5,0.7,0.75])
vomoting['veryservice'] = fuzz.trimf(vomoting.universe,[0.7,0.85,1])

jaundice['mild'] = fuzz.trimf(jaundice.universe,[0,0.1,0.25])
jaundice['moderate'] = fuzz.trimf(jaundice.universe,[0.25,0.35,0.5])
jaundice['service'] = fuzz.trimf(jaundice.universe,[0.5,0.7,0.75])
jaundice['veryservice'] = fuzz.trimf(jaundice.universe,[0.7,0.85,1])

enlargeliver['mild'] = fuzz.trimf(enlargeliver.universe,[0,0.1,0.25])
enlargeliver['moderate'] = fuzz.trimf(enlargeliver.universe,[0.25,0.35,0.5])
enlargeliver['service'] = fuzz.trimf(enlargeliver.universe,[0.5,0.7,0.75])
enlargeliver['veryservice'] = fuzz.trimf(enlargeliver.universe,[0.7,0.85,1])

jointpain['mild'] = fuzz.trimf(jointpain.universe,[0,0.1,0.25])
jointpain['moderate'] = fuzz.trimf(jointpain.universe,[0.25,0.35,0.5])
jointpain['service'] = fuzz.trimf(jointpain.universe,[0.5,0.7,0.75])
jointpain['veryservice'] = fuzz.trimf(jointpain.universe,[0.7,0.85,1])

bodyweakness['mild'] = fuzz.trimf(bodyweakness.universe,[0,0.1,0.25])
bodyweakness['moderate'] = fuzz.trimf(bodyweakness.universe,[0.25,0.35,0.5])
bodyweakness['service'] = fuzz.trimf(bodyweakness.universe,[0.5,0.7,0.75])
bodyweakness['veryservice'] = fuzz.trimf(bodyweakness.universe,[0.7,0.85,1])

dizzniness['mild'] = fuzz.trimf(dizzniness.universe,[0,0.1,0.25])
dizzniness['moderate'] = fuzz.trimf(dizzniness.universe,[0.25,0.35,0.5])
dizzniness['service'] = fuzz.trimf(dizzniness.universe,[0.5,0.7,0.75])
dizzniness['veryservice'] = fuzz.trimf(dizzniness.universe,[0.7,0.85,1])

loa['mild'] = fuzz.trimf(loa.universe,[0,0.1,0.25])
loa['moderate'] = fuzz.trimf(loa.universe,[0.25,0.35,0.5])
loa['service'] = fuzz.trimf(loa.universe,[0.5,0.7,0.75])
loa['veryservice'] = fuzz.trimf(loa.universe,[0.7,0.85,1])

mp['mild'] = fuzz.trimf(mp.universe,[0,0.1,0.25])
mp['moderate'] = fuzz.trimf(mp.universe,[0.25,0.35,0.5])
mp['service'] = fuzz.trimf(mp.universe,[0.5,0.7,0.75])
mp['very_service'] = fuzz.trimf(mp.universe,[0.7,0.85,1])

conclusion['mild'] = fuzz.trimf(conclusion.universe,[0,0.1,0.25])
conclusion['moderate'] = fuzz.trimf(conclusion.universe,[0.25,0.35,0.5])
conclusion['service'] = fuzz.trimf(conclusion.universe,[0.5,0.7,0.75])
conclusion['veryservice'] = fuzz.trimf(conclusion.universe,[0.7,0.85,1])

fever.view() 
headache.view()
nausea.view() 
vomoting.view()
jaundice.view()
enlargeliver.view()
jointpain.view()
bodyweakness.view()
dizzniness.view()
# loss of appetite
loa.view()
mp.view()
conclusion.view()

# %%
rule1 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['mild']&bodyweakness['mild']&dizzniness['service']&loa['mild']&mp['mild'],conclusion['mild'])
rule2 = ctrl.Rule(fever['moderate']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['moderate']&bodyweakness['moderate']&dizzniness['service']&loa['service']&mp['moderate'],conclusion['moderate'])
rule3 = ctrl.Rule(fever['service']&headache['moderate']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['mild']&bodyweakness['service']&dizzniness['service']&loa['service']&mp['moderate'],conclusion['service'])
rule4 = ctrl.Rule(fever['moderate']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule5 = ctrl.Rule(fever['veryservice']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule6 = ctrl.Rule(fever['service']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule7 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule8 = ctrl.Rule(fever['veryservice']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule9 = ctrl.Rule(fever['veryservice']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule10 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule11 = ctrl.Rule(fever['service']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule12 = ctrl.Rule(fever['service']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule13 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule14= ctrl.Rule(fever['veryservice']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule15= ctrl.Rule(fever['veryservice']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule16 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule17 = ctrl.Rule(fever['veryservice']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule18 = ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule19 = ctrl.Rule(fever['veryservice']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['mild']&jointpain['service']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
rule20= ctrl.Rule(fever['mild']&headache['mild']&nausea['mild']&vomoting['mild']&jaundice['mild']&enlargeliver['service']&jointpain['mild']&bodyweakness['service']&dizzniness['mild']&loa['mild']&mp['service'],conclusion['veryservice'])
diagnose_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19, rule20])
diagnose = ctrl.ControlSystemSimulation(diagnose_ctrl)

diagnose.input['fever'] = 0.1
diagnose.input['headache'] = 0.2
diagnose.input['nausea'] = 0.14
diagnose.input['vomiting'] = 0.15
diagnose.input['jaundice'] = 0.09
diagnose.input['enlargeliver'] = 0.1
diagnose.input['jointpain'] = 0.1
diagnose.input['bodyweakness'] = 0.05
diagnose.input['dizzniness'] = 0.4
diagnose.input['loa'] = 0.06
diagnose.input['mp'] = 0.1
 
diagnose.compute()

print(diagnose.output['conclusion'])
conclusion.view(sim = diagnose)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/skfuzzy/control/controlsystem.py in defuzz(self)
#     585             try:
# --> 586                 return defuzz(ups_universe, output_mf,
#     587                               self.var.defuzzify_method)
#
# /usr/local/lib/python3.8/dist-packages/skfuzzy/defuzzify/defuzz.py in defuzz(x, mfx, mode)
#     247         zero_truth_degree = mfx.sum() == 0  # Approximation of total area
# --> 248         assert not zero_truth_degree, 'Total area is zero in defuzzification!'
#     249
#
# AssertionError: Total area is zero in defuzzification!
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-b59c0f33ab73> in <module>
#      34 diagnose.input['mp'] = 0.1
#      35
# ...
